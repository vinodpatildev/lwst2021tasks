# %%
#!/usr/bin/python3

print("content-type: application/json")
print()


import subprocess as sp
import cgi
import requests
import xmltodict
import json

fs = cgi.FieldStorage()

plate_number = fs.getvalue("plate-no")

plate_number = 'MH48BE2759'


def get_vehicle_info(plate_number):
    r = requests.get("https://www.regcheck.org.uk/api/reg.asmx/CheckIndia?RegistrationNumber={}&username=tuku-tuku".format(str(plate_number)))
    print(r)
    data = xmltodict.parse(r.content)
    jdata = json.dumps(data)
    df = json.loads(jdata)
    df1 = json.loads(df['Vehicle']['vehicleJson'])
    return df1

d = get_vehicle_info(plate_number)

Description = d['Description']
RegistrationYear = d['RegistrationYear']
Company = d['CarMake']['CurrentTextValue']
Model = d['CarModel']['CurrentTextValue']
var = d['Variant']
EngineSize = d['EngineSize']['CurrentTextValue']
seats = d['NumberOfSeats']['CurrentTextValue']
inum = d['VechileIdentificationNumber']
enginenum = d['EngineNumber']
fueltype = d['FuelType']['CurrentTextValue']
regiDate = d['RegistrationDate']
owner = d['Owner']
fitness = d['Fitness']
insurance = d['Insurance']
PUCC = d['PUCC']
vehType = d['VehicleType']
location = d['Location']

print('''
<div class="row mt-2">
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Description</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Registration Year</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Company</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Model</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Variant</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Engine Size</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Number of seats</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Vehicke Identification Number</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Engine Number</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Fuel-Type</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Registration Date</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Owner Name</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Fitness</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Insurance</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">PUCC</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Vehicle Type</a></h4>
            <p class="description">{}</p>
          </div>
          <div class="col-lg-4 col-md-6 icon-box">
            <div class="icon"><i class="bi bi-briefcase"></i></div>
            <h4 class="title"><a href="">Location</a></h4>
            <p class="description">{}</p>
          </div>
                   
          
        </div>
'''.format(Description, RegistrationYear, Company, Model, var, EngineSize, seats, inum, enginenum, fueltype, regiDate, owner, fitness, insurance, PUCC,vehType,location))
# Out:
# content-type: application/json
#
# <Response [200]>
#
# <div class="row mt-2">
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Description</a></h4>
#             <p class="description">HERO HONDA PASSION PRO CAST - DRUM BRAKE</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Registration Year</a></h4>
#             <p class="description">2018</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Company</a></h4>
#             <p class="description">HERO HONDA</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Model</a></h4>
#             <p class="description">PASSION PRO</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Variant</a></h4>
#             <p class="description">CAST - DRUM BRAKE</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Engine Size</a></h4>
#             <p class="description">100</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Number of seats</a></h4>
#             <p class="description">2</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Vehicke Identification Number</a></h4>
#             <p class="description">MBLHAR186JHC33217</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Engine Number</a></h4>
#             <p class="description">HA10ACJHC68921</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Fuel-Type</a></h4>
#             <p class="description">Petrol</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Registration Date</a></h4>
#             <p class="description">07/06/2018</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Owner Name</a></h4>
#             <p class="description"></p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Fitness</a></h4>
#             <p class="description"></p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Insurance</a></h4>
#             <p class="description"></p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">PUCC</a></h4>
#             <p class="description"></p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Vehicle Type</a></h4>
#             <p class="description">M-CYCLE/SCOOTER(2WN)</p>
#           </div>
#           <div class="col-lg-4 col-md-6 icon-box">
#             <div class="icon"><i class="bi bi-briefcase"></i></div>
#             <h4 class="title"><a href="">Location</a></h4>
#             <p class="description">DY. RTO VASAI-VIRAR</p>
#           </div>
#
#
#         </div>
